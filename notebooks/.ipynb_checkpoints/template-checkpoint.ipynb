# %%
import sys
sys.path.append("../")
from YouReader.Reader import Reader

# %%
reader = Reader()
count = reader.load_captions("../data/save.json")
print("Loaded", count, "captions from save.json")
# Out:
# Loaded 1197 captions from save.json

# %%
df = reader.to_dataframe()
display(df)
# Out:
#                                                     link subject  \
# CdJgmD2-FWc  https://www.youtube.com/watch?v=CdJgmD2-FWc    BIOL
# MPxqtkch_Vg  https://www.youtube.com/watch?v=MPxqtkch_Vg    BIOL
# qLAHRGV4gXI  https://www.youtube.com/watch?v=qLAHRGV4gXI    BIOL
# 00GgiA_AHXw  https://www.youtube.com/watch?v=00GgiA_AHXw    BIOL
# 8Wya5utx1w4  https://www.youtube.com/watch?v=8Wya5utx1w4    BIOL
# ...                                                  ...     ...
# ttEU0_850Xc  https://www.youtube.com/watch?v=ttEU0_850Xc   PSYCH
# JuaVAQk6_dU  https://www.youtube.com/watch?v=JuaVAQk6_dU   PSYCH
# fq_MMDQ4HCc  https://www.youtube.com/watch?v=fq_MMDQ4HCc   PSYCH
# i67N6Jt_1RY  https://www.youtube.com/watch?v=i67N6Jt_1RY   PSYCH
# yQ91EfJEevk  https://www.youtube.com/watch?v=yQ91EfJEevk   PSYCH
#
#                                              notes  \
# CdJgmD2-FWc  Professor Fink Human Anatomy Lectures
# MPxqtkch_Vg  Professor Fink Human Anatomy Lectures
# qLAHRGV4gXI  Professor Fink Human Anatomy Lectures
# 00GgiA_AHXw  Professor Fink Human Anatomy Lectures
# 8Wya5utx1w4  Professor Fink Human Anatomy Lectures
# ...                                            ...
# ttEU0_850Xc                     I/O PSYCH LECTURES
# JuaVAQk6_dU                     I/O PSYCH LECTURES
# fq_MMDQ4HCc                     I/O PSYCH LECTURES
# i67N6Jt_1RY                     I/O PSYCH LECTURES
# yQ91EfJEevk                     I/O PSYCH LECTURES
#
#                                                            raw  \
# CdJgmD2-FWc  1\n00:00:08,790 --> 00:00:18,990\nokay um all ...
# MPxqtkch_Vg  1\n00:00:06,850 --> 00:00:13,420\nso another e...
# qLAHRGV4gXI  1\n00:00:08,290 --> 00:00:14,450\nall right so...
# 00GgiA_AHXw  1\n00:00:06,660 --> 00:00:10,840\nlet me go ju...
# 8Wya5utx1w4  1\n00:00:06,570 --> 00:00:13,920\nall right th...
# ...                                                        ...
# ttEU0_850Xc  1\n00:00:00,110 --> 00:00:05,640\nhello there ...
# JuaVAQk6_dU  1\n00:00:00,410 --> 00:00:06,720\nhello there ...
# fq_MMDQ4HCc  1\n00:00:00,050 --> 00:00:04,920\nhello there ...
# i67N6Jt_1RY  1\n00:00:00,030 --> 00:00:06,600\nhello there ...
# yQ91EfJEevk  1\n00:00:00,030 --> 00:00:04,890\nhello there ...
#
#                                                          clean
# CdJgmD2-FWc  okay um all right so we're going to\n\nbegin t...
# MPxqtkch_Vg  so another example of posterior is the\n\nrect...
# qLAHRGV4gXI  all right so this is a page b1 now the\n\nfirs...
# 00GgiA_AHXw  let me go just a drop further and then\n\nwe'l...
# 8Wya5utx1w4  all right this is page m3 let's start\n\nhere ...
# ...                                                        ...
# ttEU0_850Xc  hello there and welcome to part 2 of\n\nyour c...
# JuaVAQk6_dU  hello there this lecture is just going\n\nto f...
# fq_MMDQ4HCc  hello there this lecture video is going\n\nto ...
# i67N6Jt_1RY  hello there this video is all about job\n\nand...
# yQ91EfJEevk  hello there this video is going to give\n\nyou...
#
# [1043 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer,TfidfTransformer
from sklearn.cluster import AgglomerativeClustering
from pprint import pprint
import time

# %%
start_time = time.time()

# %%
from pytube import YouTube
from pytube import Playlist
link = 'https://www.youtube.com/watch?v=wjTn_EkgQRg&index=1&list=PLgJ7b1NurjD2oN5ZXbKbPjuI04d_S0V1K'
playlist = Playlist('https://www.youtube.com/playlist?list=PLF797E961509B4EB5') 
        
        
def getTranscript(p):
    for link in p.video_urls:
        #print (urls)
        source = YouTube(link)

        en_caption = source.captions['a.en']

        en_caption_convert_to_srt = (en_caption.generate_srt_captions())

        print(en_caption_convert_to_srt)
                #save the caption to a file named Output.txt
        text_file = open("Output.txt", "w")
        text_file.write(en_caption_convert_to_srt)
        text_file.close()

# %%
getTranscript(playlist)
# Out:
# 1
# 00:00:00,030 --> 00:00:04,140
# well welcome to the official start of
#
# 2
# 00:00:02,250 --> 00:00:06,480
# calculus congratulations you made it in
#
# 3
# 00:00:04,140 --> 00:00:08,580
# the class today we're going to talk
#
# 4
# 00:00:06,480 --> 00:00:10,530
# about a review a review of a lot of the
#
# 5
# 00:00:08,580 --> 00:00:12,420
# math two concepts and some basic algebra
#
# 6
# 00:00:10,530 --> 00:00:14,519
# concepts that you really need to have
#
# 7
# 00:00:12,420 --> 00:00:16,440
# down in order for you to be successful
#
# 8
# 00:00:14,519 --> 00:00:18,270
# in calculus the first place we're going
#
# 9
# 00:00:16,440 --> 00:00:19,710
# to start is section zero point one
#
# 10
# 00:00:18,270 --> 00:00:21,630
# chapter zero we're going to talk about
#
# 11
# 00:00:19,710 --> 00:00:23,039
# lines just basic lines we're going to go
#
# 12
# 00:00:21,630 --> 00:00:25,019
# through some families of curves we'll
#
# 13
# 00:00:23,039 --> 00:00:27,300
# give you some trig functions your
#
# 14
# 00:00:25,019 --> 00:00:30,170
# favorite right and then we'll we'll get
#
# 15
# 00:00:27,300 --> 00:00:30,170
# to the capital itself
#
# 16
# 00:00:36,910 --> 00:00:50,379
# lots of weird minds what's special about
#
# 17
# 00:00:44,710 --> 00:00:52,480
# a line what do you know about lines love
#
# 18
# 00:00:50,379 --> 00:00:54,760
# it have infinite points but specifically
#
# 19
# 00:00:52,480 --> 00:00:57,269
# you need at least two right why don't
#
# 20
# 00:00:54,760 --> 00:01:03,070
# you give up lines they curve it all
#
# 21
# 00:00:57,269 --> 00:01:04,239
# do they curve lines do the end what what
#
# 22
# 00:01:03,070 --> 00:01:08,680
# do you need to know about a line in
#
# 23
# 00:01:04,239 --> 00:01:10,780
# order to graph it you need two points or
#
# 24
# 00:01:08,680 --> 00:01:13,450
# I need one point and specifically one of
#
# 25
# 00:01:10,780 --> 00:01:16,390
# the lines have slope they're straight
#
# 26
# 00:01:13,450 --> 00:01:17,409
# they don't end that slope in fact the
#
# 27
# 00:01:16,390 --> 00:01:20,770
# slope is what we're going to talk about
#
# 28
# 00:01:17,409 --> 00:01:22,659
# for the first part of today the slope is
#
# 29
# 00:01:20,770 --> 00:01:24,039
# pretty much how a line Rises or Falls
#
# 30
# 00:01:22,659 --> 00:01:25,630
# now you might have been walked through
#
# 31
# 00:01:24,039 --> 00:01:27,850
# this a long time ago we're going to go
#
# 32
# 00:01:25,630 --> 00:01:29,409
# really quickly through how to find the
#
# 33
# 00:01:27,850 --> 00:01:31,119
# slope of a line and we're going to
#
# 34
# 00:01:29,409 --> 00:01:34,509
# invent the formula ourselves so let's
#
# 35
# 00:01:31,119 --> 00:01:36,159
# take a generic line and we'll pick two
#
# 36
# 00:01:34,509 --> 00:01:37,659
# random points on it we're not going to
#
# 37
# 00:01:36,159 --> 00:01:39,369
# be specific on it because it in order to
#
# 38
# 00:01:37,659 --> 00:01:41,320
# create a formula you can't really say
#
# 39
# 00:01:39,369 --> 00:01:43,689
# something specific like any particular
#
# 40
# 00:01:41,320 --> 00:01:46,119
# point we need to work for all points can
#
# 41
# 00:01:43,689 --> 00:01:48,610
# you tell me if I've got two points how
#
# 42
# 00:01:46,119 --> 00:01:50,850
# can I make a distinction between these
#
# 43
# 00:01:48,610 --> 00:01:52,479
# well what does every point have
#
# 44
# 00:01:50,850 --> 00:01:54,070
# coordinates what are the corners
#
# 45
# 00:01:52,479 --> 00:01:57,340
# somewhere over here what are the corners
#
# 46
# 00:01:54,070 --> 00:02:02,770
# generally for a point excellent okay so
#
# 47
# 00:01:57,340 --> 00:02:03,969
# we know that any point that we draw is
#
# 48
# 00:02:02,770 --> 00:02:08,739
# going to have the coordinates X Y this
#
# 49
# 00:02:03,969 --> 00:02:10,570
# one will and this one will but the
#
# 50
# 00:02:08,739 --> 00:02:12,549
# problem is we need some way to tell a
#
# 51
# 00:02:10,570 --> 00:02:16,420
# difference between those those two
#
# 52
# 00:02:12,549 --> 00:02:18,280
# points how are we going to do it with
#
# 53
# 00:02:16,420 --> 00:02:21,370
# some VI with some numbers what are those
#
# 54
# 00:02:18,280 --> 00:02:25,630
# what numbers are they going to go on top
#
# 55
# 00:02:21,370 --> 00:02:26,750
# of our X or below our X and please we're
#
# 56
# 00:02:25,630 --> 00:02:28,790
# done
#
# 57
# 00:02:26,750 --> 00:02:29,960
# if I put up here we're talking about X
#
# 58
# 00:02:28,790 --> 00:02:35,000
# to the first power so we're going to put
#
# 59
# 00:02:29,960 --> 00:02:36,770
# an X to the X 1 and X 2 a 1 1 or Y 2
#
# 60
# 00:02:35,000 --> 00:02:38,150
# saying that this is our our first point
#
# 61
# 00:02:36,770 --> 00:02:40,640
# in our second point whatever those
#
# 62
# 00:02:38,150 --> 00:02:42,320
# points may be we can't use real numbers
#
# 63
# 00:02:40,640 --> 00:02:44,960
# because then it wouldn't work in general
#
# 64
# 00:02:42,320 --> 00:02:55,340
# 42 points can you tell me along the
#
# 65
# 00:02:44,960 --> 00:02:57,880
# x-axis how far is is this one 1 if this
#
# 66
# 00:02:55,340 --> 00:03:01,550
# is the point x1 y1 how far is that
#
# 67
# 00:02:57,880 --> 00:03:05,390
# yeah it's x1 for sure how far is this
#
# 68
# 00:03:01,550 --> 00:03:07,850
# point yeah
#
# 69
# 00:03:05,390 --> 00:03:10,209
# okay is within this budget if you're all
#
# 70
# 00:03:07,850 --> 00:03:13,730
# right so far if you're not Gilligan some
#
# 71
# 00:03:10,209 --> 00:03:17,630
# we okay or no all right if this was like
#
# 72
# 00:03:13,730 --> 00:03:20,180
# the point of 3 comma 5 to get to 3 comma
#
# 73
# 00:03:17,630 --> 00:03:22,160
# 5 you go over 3 and up five right so
#
# 74
# 00:03:20,180 --> 00:03:25,790
# then this would be three this is not 3
#
# 75
# 00:03:22,160 --> 00:03:32,830
# 12 5 it's x1 y1 so we're going over x1
#
# 76
# 00:03:25,790 --> 00:03:37,100
# how far are we going up good and here
#
# 77
# 00:03:32,830 --> 00:03:38,480
# now when we talk about smoke typically a
#
# 78
# 00:03:37,100 --> 00:03:40,370
# long time ago when you're first
#
# 79
# 00:03:38,480 --> 00:03:42,380
# introduced the slope the teacher
#
# 80
# 00:03:40,370 --> 00:03:45,430
# probably said yeah it's how your line
#
# 81
# 00:03:42,380 --> 00:03:49,850
# Rises or Falls but then they also said
#
# 82
# 00:03:45,430 --> 00:03:51,410
# slope is defined as 1 over what let's go
#
# 83
# 00:03:49,850 --> 00:03:57,769
# ahead let's try to identify what our
#
# 84
# 00:03:51,410 --> 00:04:01,600
# Rises and what our run is what would you
#
# 85
# 00:03:57,769 --> 00:04:03,860
# say would be our rise this way this way
#
# 86
# 00:04:01,600 --> 00:04:05,510
# so if we find the difference between
#
# 87
# 00:04:03,860 --> 00:04:07,190
# those two numbers over there we're going
#
# 88
# 00:04:05,510 --> 00:04:09,380
# to find the rise for our line what is
#
# 89
# 00:04:07,190 --> 00:04:12,230
# the difference between those two numbers
#
# 90
# 00:04:09,380 --> 00:04:14,230
# over there how do you find the
#
# 91
# 00:04:12,230 --> 00:04:18,709
# difference this distance here right
#
# 92
# 00:04:14,230 --> 00:04:20,660
# sure yeah if this was 10 and this was 3
#
# 93
# 00:04:18,709 --> 00:04:22,850
# the distance between them would be what
#
# 94
# 00:04:20,660 --> 00:04:24,200
# okay you'd subtract it right you do 10
#
# 95
# 00:04:22,850 --> 00:04:29,120
# minus 3 so here we're going to go well
#
# 96
# 00:04:24,200 --> 00:04:33,970
# it's not 10 and 3 its y2 and y1 so our
#
# 97
# 00:04:29,120 --> 00:04:33,970
# rise we're going to call y2 minus 1 1
#
# 98
# 00:04:35,379 --> 00:04:39,699
# can we do the same thing with the run
#
# 99
# 00:04:39,970 --> 00:04:47,300
# how far is our run what's that distance
#
# 100
# 00:04:44,150 --> 00:04:49,430
# represent the representatives taking you
#
# 101
# 00:04:47,300 --> 00:04:50,990
# - one I thought you're going to answer
#
# 102
# 00:04:49,430 --> 00:04:53,720
# you instead you sneezed I was like she's
#
# 103
# 00:04:50,990 --> 00:05:02,599
# off and then John it it's a pretty good
#
# 104
# 00:04:53,720 --> 00:05:03,610
# one yeah we got x2 - x1 for sure sound
#
# 105
# 00:05:02,599 --> 00:05:06,500
# familiar
#
# 106
# 00:05:03,610 --> 00:05:08,180
# yeah if we use the letter instead of the
#
# 107
# 00:05:06,500 --> 00:05:10,250
# word slow what letter - am i talking
#
# 108
# 00:05:08,180 --> 00:05:12,699
# later we use em and step slope we got
#
# 109
# 00:05:10,250 --> 00:05:12,699
# our formula
#
# 110
# 00:05:19,030 --> 00:05:22,870
# we're just kind of you've seen it before
#
# 111
# 00:05:20,770 --> 00:05:25,390
# right you probably saw anything invented
#
# 112
# 00:05:22,870 --> 00:05:26,950
# before like this if you haven't well
#
# 113
# 00:05:25,390 --> 00:05:28,900
# something new for you have well you've
#
# 114
# 00:05:26,950 --> 00:05:30,670
# seen it again this is how you invent the
#
# 115
# 00:05:28,900 --> 00:05:32,230
# slope formula the reason why we couldn't
#
# 116
# 00:05:30,670 --> 00:05:34,330
# use specific points is because we want
#
# 117
# 00:05:32,230 --> 00:05:35,200
# to be able to plug in any two points
#
# 118
# 00:05:34,330 --> 00:05:37,870
# that I give you right
#
# 119
# 00:05:35,200 --> 00:05:39,340
# so using that if you call your points x1
#
# 120
# 00:05:37,870 --> 00:05:42,640
# y1 x2 y2
#
# 121
# 00:05:39,340 --> 00:05:44,710
# you can find a slope for anything now
#
# 122
# 00:05:42,640 --> 00:05:46,150
# the one reason why I invent this for you
#
# 123
# 00:05:44,710 --> 00:05:48,430
# is I want to show you that we can
#
# 124
# 00:05:46,150 --> 00:05:51,040
# actually create an equation from that
#
# 125
# 00:05:48,430 --> 00:05:52,510
# equation for a line from that slope
#
# 126
# 00:05:51,040 --> 00:06:01,419
# formula so let's talk just a bit about
#
# 127
# 00:05:52,510 --> 00:06:04,270
# equations what we're going to do is
#
# 128
# 00:06:01,419 --> 00:06:07,000
# we're going to manipulate that formula
#
# 129
# 00:06:04,270 --> 00:06:08,440
# by fixing one point we're going to be
#
# 130
# 00:06:07,000 --> 00:06:09,580
# able to get the formula for lines so
#
# 131
# 00:06:08,440 --> 00:06:11,830
# here's what we're going to work with
#
# 132
# 00:06:09,580 --> 00:06:17,530
# we're going to start with M equals y2
#
# 133
# 00:06:11,830 --> 00:06:20,230
# minus y1 over x2 minus x1 what I'm going
#
# 134
# 00:06:17,530 --> 00:06:23,050
# to do is I'm going to fix this point say
#
# 135
# 00:06:20,230 --> 00:06:25,690
# this is any specific one point and let
#
# 136
# 00:06:23,050 --> 00:06:29,020
# the other one float what that does is it
#
# 137
# 00:06:25,690 --> 00:06:32,590
# changes this formula into this formula
#
# 138
# 00:06:29,020 --> 00:06:34,000
# instead of y2 minus y1 there's no more
#
# 139
# 00:06:32,590 --> 00:06:35,950
# y2 you see here's the thing
#
# 140
# 00:06:34,000 --> 00:06:38,260
# a fixed point is a point with a little
#
# 141
# 00:06:35,950 --> 00:06:41,229
# number under a subscript like this would
#
# 142
# 00:06:38,260 --> 00:06:44,050
# be a specific fixed point x1 y1 this is
#
# 143
# 00:06:41,229 --> 00:06:46,180
# a specific fixed point x2 y2 what I'm
#
# 144
# 00:06:44,050 --> 00:06:48,040
# doing by fixing one point only one point
#
# 145
# 00:06:46,180 --> 00:06:51,270
# I'm saying that's the one point I'm
#
# 146
# 00:06:48,040 --> 00:06:55,180
# fixing x1 y1 I'm let the other one be
#
# 147
# 00:06:51,270 --> 00:06:58,150
# floating so I'm going to erase that y2
#
# 148
# 00:06:55,180 --> 00:07:04,090
# and x2 that means I'm going to have Y
#
# 149
# 00:06:58,150 --> 00:07:06,610
# minus y1 over X minus x1 that says 1
#
# 150
# 00:07:04,090 --> 00:07:08,470
# points fixed this point is going to be
#
# 151
# 00:07:06,610 --> 00:07:10,090
# formulaic it means you can plug in an X
#
# 152
# 00:07:08,470 --> 00:07:12,460
# and get out of Y you ever seen the
#
# 153
# 00:07:10,090 --> 00:07:13,419
# equation for a line not your head you've
#
# 154
# 00:07:12,460 --> 00:07:16,210
# always seen it because you're all here
#
# 155
# 00:07:13,419 --> 00:07:18,850
# right it has places for you to plug in X
#
# 156
# 00:07:16,210 --> 00:07:20,110
# and get outlined in it so we need that
#
# 157
# 00:07:18,850 --> 00:07:21,610
# inherently otherwise we don't have the
#
# 158
# 00:07:20,110 --> 00:07:22,960
# equation for a line we have a specific
#
# 159
# 00:07:21,610 --> 00:07:25,060
# two points we don't want that we want
#
# 160
# 00:07:22,960 --> 00:07:27,010
# equation for a line here's the cool
#
# 161
# 00:07:25,060 --> 00:07:29,770
# thing is there a way that you can solve
#
# 162
# 00:07:27,010 --> 00:07:31,779
# for y minus y1 how would you get rid of
#
# 163
# 00:07:29,770 --> 00:07:34,939
# this denominator
#
# 164
# 00:07:31,779 --> 00:07:38,419
# do what someone said I can just will
#
# 165
# 00:07:34,939 --> 00:07:45,080
# have bad ears multiply on one side or
#
# 166
# 00:07:38,419 --> 00:07:48,710
# both sides so if I multiply this by all
#
# 167
# 00:07:45,080 --> 00:07:56,659
# don't work cool X minus x1 and over here
#
# 168
# 00:07:48,710 --> 00:07:57,169
# X minus x1 is this gone you guys are so
#
# 169
# 00:07:56,659 --> 00:07:59,539
# quiet
#
# 170
# 00:07:57,169 --> 00:08:02,089
# is this gone and I can't ever know for
#
# 171
# 00:07:59,539 --> 00:08:08,389
# sure for sure on the right hand side
#
# 172
# 00:08:02,089 --> 00:08:10,339
# tell me what I'm left with on the left
#
# 173
# 00:08:08,389 --> 00:08:11,990
# hand side I'm going to reorganize this
#
# 174
# 00:08:10,339 --> 00:08:17,569
# I'm not going to have X minus X 1 times
#
# 175
# 00:08:11,990 --> 00:08:19,330
# M I'm going to M times X minus x1 you
#
# 176
# 00:08:17,569 --> 00:08:21,020
# still okay with that so far
#
# 177
# 00:08:19,330 --> 00:08:22,399
# multiplication is commutative didn't
#
# 178
# 00:08:21,020 --> 00:08:24,289
# matter what I have first we have second
#
# 179
# 00:08:22,399 --> 00:08:26,059
# Oh problem maybe you're not familiar
#
# 180
# 00:08:24,289 --> 00:08:33,680
# with it written this way but I'll bet
#
# 181
# 00:08:26,059 --> 00:08:37,310
# you've seen this before work yeah what
#
# 182
# 00:08:33,680 --> 00:08:39,740
# is that called just think no no it's not
#
# 183
# 00:08:37,310 --> 00:08:41,180
# slope-intercept point-slope why is it
#
# 184
# 00:08:39,740 --> 00:08:41,990
# called point-slope mathematicians are
#
# 185
# 00:08:41,180 --> 00:08:43,639
# very unoriginal
#
# 186
# 00:08:41,990 --> 00:08:45,560
# it's called point-slope because it's
#
# 187
# 00:08:43,639 --> 00:08:49,370
# named after what you need to complete it
#
# 188
# 00:08:45,560 --> 00:08:52,100
# you need a point and slope this what's
#
# 189
# 00:08:49,370 --> 00:08:53,870
# called point slope so by manipulating
#
# 190
# 00:08:52,100 --> 00:08:55,850
# our slope form is interesting in that we
#
# 191
# 00:08:53,870 --> 00:08:57,560
# use this we fixed only one point let
#
# 192
# 00:08:55,850 --> 00:09:00,880
# that of a float worked around a little
#
# 193
# 00:08:57,560 --> 00:09:00,880
# bit we now have point slope
#
# 194
# 00:09:08,080 --> 00:09:11,440
# pretty useful stuff shall we shall we do
#
# 195
# 00:09:10,420 --> 00:09:13,750
# an example would you like to see
#
# 196
# 00:09:11,440 --> 00:09:16,029
# something that we can use the stuff
#
# 197
# 00:09:13,750 --> 00:09:17,830
# would I think you've said before it
#
# 198
# 00:09:16,029 --> 00:09:19,540
# should be reviewed for you but let's go
#
# 199
# 00:09:17,830 --> 00:09:21,550
# ahead let's see if we can first get the
#
# 200
# 00:09:19,540 --> 00:09:22,839
# cobwebs out of your head because I know
#
# 201
# 00:09:21,550 --> 00:09:24,970
# you weren't doing math over Christmas
#
# 202
# 00:09:22,839 --> 00:09:26,740
# break we're or holiday break whatever
#
# 203
# 00:09:24,970 --> 00:09:29,649
# you're doing what are you doing math I
#
# 204
# 00:09:26,740 --> 00:09:31,390
# was I was I was redoing this class to
#
# 205
# 00:09:29,649 --> 00:09:33,160
# make an extra super special for you you
#
# 206
# 00:09:31,390 --> 00:09:35,350
# should feel honored but let's go ahead
#
# 207
# 00:09:33,160 --> 00:09:37,330
# and try to find the equation of the line
#
# 208
# 00:09:35,350 --> 00:09:38,680
# passes through these two points look at
#
# 209
# 00:09:37,330 --> 00:09:41,459
# the couples or a head will try to use a
#
# 210
# 00:09:38,680 --> 00:09:46,770
# slope formula and then use point slope
#
# 211
# 00:09:41,459 --> 00:09:46,770
# with what points so find the equation
#
# 212
# 00:09:57,270 --> 00:10:00,320
# through these two points
#
# 213
# 00:10:07,050 --> 00:10:11,370
# whenever your teacher taught you how to
#
# 214
# 00:10:09,390 --> 00:10:13,830
# find the equation of a line they taught
#
# 215
# 00:10:11,370 --> 00:10:16,140
# you you need absolutely have to have two
#
# 216
# 00:10:13,830 --> 00:10:19,020
# things you have to have one
#
# 217
# 00:10:16,140 --> 00:10:21,860
# what if F one point very good and
#
# 218
# 00:10:19,020 --> 00:10:24,570
# something else you also have to know the
#
# 219
# 00:10:21,860 --> 00:10:27,050
# get little slope or be able to find the
#
# 220
# 00:10:24,570 --> 00:10:29,400
# slope firstly do we have a point
#
# 221
# 00:10:27,050 --> 00:10:32,220
# actually a two of them we're set right
#
# 222
# 00:10:29,400 --> 00:10:35,100
# do we have a slope is it given to you
#
# 223
# 00:10:32,220 --> 00:10:39,720
# right now can you find it you know go
#
# 224
# 00:10:35,100 --> 00:10:40,740
# ahead and find it by the way you should
#
# 225
# 00:10:39,720 --> 00:10:41,700
# do this I'll walk around the room if you
#
# 226
# 00:10:40,740 --> 00:10:43,230
# need help at this point
#
# 227
# 00:10:41,700 --> 00:10:44,700
# let me know is now would be a good time
#
# 228
# 00:10:43,230 --> 00:10:47,160
# for me to help you what it wants to do
#
# 229
# 00:10:44,700 --> 00:10:48,750
# right now is find the slope if you don't
#
# 230
# 00:10:47,160 --> 00:10:52,440
# remember how to find the slope you
#
# 231
# 00:10:48,750 --> 00:10:54,960
# assign x1 y1 to one point x2 y2 to one
#
# 232
# 00:10:52,440 --> 00:10:57,650
# point and plug it in that formula go
#
# 233
# 00:10:54,960 --> 00:10:57,650
# ahead and try that right now
#
# 234
# 00:11:09,580 --> 00:11:11,580
# Oh
#
# 235
# 00:11:31,650 --> 00:11:34,770
# okay let's see what y'all did I just
#
# 236
# 00:11:33,660 --> 00:11:36,660
# want the slope for now we work on the
#
# 237
# 00:11:34,770 --> 00:11:38,250
# equation just a second so as far as the
#
# 238
# 00:11:36,660 --> 00:11:40,470
# slope goes we need to pick one of these
#
# 239
# 00:11:38,250 --> 00:11:43,170
# points to be x1 y1 another point to be
#
# 240
# 00:11:40,470 --> 00:11:45,300
# x2 y2 just got to make sure it goes X Y
#
# 241
# 00:11:43,170 --> 00:11:46,830
# and it goes 1 1 & 2 2 right those
#
# 242
# 00:11:45,300 --> 00:11:48,150
# numbers got to be together and you have
#
# 243
# 00:11:46,830 --> 00:11:53,220
# to have an alphabetic order you can't go
#
# 244
# 00:11:48,150 --> 00:11:56,490
# Y X which is going to be your x1 do pick
#
# 245
# 00:11:53,220 --> 00:11:57,120
# negative 2 for your x1 it really doesn't
#
# 246
# 00:11:56,490 --> 00:11:59,940
# matter does it
#
# 247
# 00:11:57,120 --> 00:12:01,589
# I could pick this one as x1 but then
#
# 248
# 00:11:59,940 --> 00:12:03,660
# that would have to be y1 so once you
#
# 249
# 00:12:01,589 --> 00:12:05,430
# pick one letter the rest of them have to
#
# 250
# 00:12:03,660 --> 00:12:07,230
# fall into place now typically people
#
# 251
# 00:12:05,430 --> 00:12:13,589
# just want to make it easy and they put
#
# 252
# 00:12:07,230 --> 00:12:15,120
# this one x1 y1 x2 and y2 which I'm
#
# 253
# 00:12:13,589 --> 00:12:16,680
# guessing most of you did that one the
#
# 254
# 00:12:15,120 --> 00:12:18,570
# other way you're going to get the same
#
# 255
# 00:12:16,680 --> 00:12:20,010
# exact slope just sure if you had a
#
# 256
# 00:12:18,570 --> 00:12:23,370
# negative or signs can be in the
#
# 257
# 00:12:20,010 --> 00:12:25,800
# offensive spot not going to you let's go
#
# 258
# 00:12:23,370 --> 00:12:27,779
# ahead and plug this end we have y2 minus
#
# 259
# 00:12:25,800 --> 00:12:31,890
# y1 what am I going to write down if I'm
#
# 260
# 00:12:27,779 --> 00:12:36,029
# supposed to do y2 minus y1 right now -
#
# 261
# 00:12:31,890 --> 00:12:37,620
# like that - okay good so we're
#
# 262
# 00:12:36,029 --> 00:12:39,930
# subtracting but that also has a negative
#
# 263
# 00:12:37,620 --> 00:12:41,339
# sign I'll be real careful about them and
#
# 264
# 00:12:39,930 --> 00:12:43,470
# put it in parentheses to show that I'm
#
# 265
# 00:12:41,339 --> 00:12:45,029
# subtracting an 8
#
# 266
# 00:12:43,470 --> 00:12:48,810
# what is subtracting negative what's that
#
# 267
# 00:12:45,029 --> 00:12:51,959
# become great okay flood yeah it ends up
#
# 268
# 00:12:48,810 --> 00:12:55,620
# being addition and then for x2 minus x1
#
# 269
# 00:12:51,959 --> 00:12:59,070
# we're going to have our 8 minus negative
#
# 270
# 00:12:55,620 --> 00:13:05,100
# 2 same idea what is our 2 minus negative
#
# 271
# 00:12:59,070 --> 00:13:10,110
# 3 times we get over can you reduce
#
# 272
# 00:13:05,100 --> 00:13:11,279
# slopes absolutely what is it a quick
#
# 273
# 00:13:10,110 --> 00:13:14,339
# show hands how many people were able to
#
# 274
# 00:13:11,279 --> 00:13:15,959
# find the slope good start here but
#
# 275
# 00:13:14,339 --> 00:13:16,260
# that's fine if you're not work on that
#
# 276
# 00:13:15,959 --> 00:13:18,150
# later
#
# 277
# 00:13:16,260 --> 00:13:19,410
# okay revisit this try to follow through
#
# 278
# 00:13:18,150 --> 00:13:23,630
# this example see if you're doing it own
#
# 279
# 00:13:19,410 --> 00:13:25,950
# and then come up that 1/2 I'll be done
#
# 280
# 00:13:23,630 --> 00:13:29,220
# we're about halfway there can we have
#
# 281
# 00:13:25,950 --> 00:13:30,720
# the slope do we have a point still if
#
# 282
# 00:13:29,220 --> 00:13:31,800
# we've got a point that we get the slope
#
# 283
# 00:13:30,720 --> 00:13:34,560
# we should be able to fill out
#
# 284
# 00:13:31,800 --> 00:13:36,870
# point-slope it's actually the same exact
#
# 285
# 00:13:34,560 --> 00:13:38,370
# formula as slope we just have now fixed
#
# 286
# 00:13:36,870 --> 00:13:40,889
# one point and we have
#
# 287
# 00:13:38,370 --> 00:13:43,709
# it's kind of good so we know where you
#
# 288
# 00:13:40,889 --> 00:13:45,449
# thought Y minus y1 check out if you
#
# 289
# 00:13:43,709 --> 00:13:46,740
# already have your y1 you can leave it if
#
# 290
# 00:13:45,449 --> 00:13:48,059
# you want to make it easier on yourself
#
# 291
# 00:13:46,740 --> 00:13:49,649
# and not deal with those negatives you
#
# 292
# 00:13:48,059 --> 00:13:50,970
# can use that point that define as well
#
# 293
# 00:13:49,649 --> 00:13:52,860
# it doesn't matter what point you have
#
# 294
# 00:13:50,970 --> 00:13:54,449
# after you've already identified your
#
# 295
# 00:13:52,860 --> 00:13:57,089
# slope here I'm going to stick with the
#
# 296
# 00:13:54,449 --> 00:13:59,670
# same one to keep it kind of continuous
#
# 297
# 00:13:57,089 --> 00:14:05,069
# for us so we have Y what am I gonna
#
# 298
# 00:13:59,670 --> 00:14:06,600
# write perfect okay again I will use some
#
# 299
# 00:14:05,069 --> 00:14:09,269
# parentheses saying that's a negative
#
# 300
# 00:14:06,600 --> 00:14:18,480
# number in there equals I'm so sad my M
#
# 301
# 00:14:09,269 --> 00:14:19,800
# what's my M and X perfect let's clean
#
# 302
# 00:14:18,480 --> 00:14:27,059
# this up just a little bit we're going to
#
# 303
# 00:14:19,800 --> 00:14:29,129
# have y plus 3 equals 1/2 X plus 2 if
#
# 304
# 00:14:27,059 --> 00:14:31,709
# it's asking for point-slope you know
#
# 305
# 00:14:29,129 --> 00:14:34,079
# what you're done it that that's it but
#
# 306
# 00:14:31,709 --> 00:14:36,569
# this isn't exactly the easiest way to
#
# 307
# 00:14:34,079 --> 00:14:39,389
# graph a line is it like that is there a
#
# 308
# 00:14:36,569 --> 00:14:40,410
# way we can make it easier what would you
#
# 309
# 00:14:39,389 --> 00:14:41,670
# do
#
# 310
# 00:14:40,410 --> 00:14:43,319
# sure we want to get rid of those
#
# 311
# 00:14:41,670 --> 00:14:44,819
# parentheses we'll distribute that if we
#
# 312
# 00:14:43,319 --> 00:14:47,910
# just hit the right side I'm swimming am
#
# 313
# 00:14:44,819 --> 00:14:51,600
# is y plus 3 but I'm going to get 1/2 X
#
# 314
# 00:14:47,910 --> 00:14:52,139
# plus 1 good 1/2 times 2 that's going to
#
# 315
# 00:14:51,600 --> 00:14:57,389
# give us 1
#
# 316
# 00:14:52,139 --> 00:15:01,910
# and lastly less tip is what yeah if I do
#
# 317
# 00:14:57,389 --> 00:15:01,910
# that I'm going to get y equals 1/2 X
#
# 318
# 00:15:02,089 --> 00:15:05,579
# that's something we're real familiar
#
# 319
# 00:15:04,110 --> 00:15:06,899
# with we know how to graph that pretty
#
# 320
# 00:15:05,579 --> 00:15:10,139
# well in X Y axis
#
# 321
# 00:15:06,899 --> 00:15:17,309
# what is that call by the way yeah
#
# 322
# 00:15:10,139 --> 00:15:19,079
# whenever we have y equals MX plus B when
#
# 323
# 00:15:17,309 --> 00:15:21,029
# we have some number times X plus or
#
# 324
# 00:15:19,079 --> 00:15:22,199
# minus some constant we know that that's
#
# 325
# 00:15:21,029 --> 00:15:23,939
# going to be called with that is
#
# 326
# 00:15:22,199 --> 00:15:25,139
# slope-intercept it's pretty easy to
#
# 327
# 00:15:23,939 --> 00:15:28,759
# graph it gives you what you need to
#
# 328
# 00:15:25,139 --> 00:15:28,759
# graph a line very quickly
#
# 329
# 00:15:33,950 --> 00:15:36,740
# and again the reason why it's called
#
# 330
# 00:15:35,450 --> 00:15:38,899
# slope-intercept is that's what you have
#
# 331
# 00:15:36,740 --> 00:15:42,050
# that animal well that's our slope what's
#
# 332
# 00:15:38,899 --> 00:15:44,380
# the B stand for yeah I could find
#
# 333
# 00:15:42,050 --> 00:15:44,380
# yourself
#
# 334
# 00:15:56,029 --> 00:16:01,699
# can you graph it let me just graph how
#
# 335
# 00:15:59,480 --> 00:16:03,350
# would you grab something with 1/2 X
#
# 336
# 00:16:01,699 --> 00:16:07,699
# minus 2 can you tell me what is my
#
# 337
# 00:16:03,350 --> 00:16:09,649
# y-intercept in this case so when we're
#
# 338
# 00:16:07,699 --> 00:16:10,910
# graphing slope intercept that says if we
#
# 339
# 00:16:09,649 --> 00:16:14,480
# have a negative 2 that means we're going
#
# 340
# 00:16:10,910 --> 00:16:17,089
# down or left which what that means
#
# 341
# 00:16:14,480 --> 00:16:18,290
# so we know our wise is down to and says
#
# 342
# 00:16:17,089 --> 00:16:20,259
# we're going to put a point right there
#
# 343
# 00:16:18,290 --> 00:16:22,819
# that's where our minus 2 is coming from
#
# 344
# 00:16:20,259 --> 00:16:24,230
# next we use our slope from the point
#
# 345
# 00:16:22,819 --> 00:16:25,939
# that we just graph not the origin with
#
# 346
# 00:16:24,230 --> 00:16:28,550
# the point we've just plotted to find our
#
# 347
# 00:16:25,939 --> 00:16:32,720
# next point our slope is what was it is
#
# 348
# 00:16:28,550 --> 00:16:36,139
# that up or down up how many and over to
#
# 349
# 00:16:32,720 --> 00:16:37,519
# the over to the right how many yeah the
#
# 350
# 00:16:36,139 --> 00:16:39,620
# positive or negative tells you whether
#
# 351
# 00:16:37,519 --> 00:16:43,069
# you're going up or down you always go to
#
# 352
# 00:16:39,620 --> 00:16:44,990
# the right so if we had negative 1/2 that
#
# 353
# 00:16:43,069 --> 00:16:46,939
# would say go down 1 but you're still
#
# 354
# 00:16:44,990 --> 00:16:48,680
# going to the right you're always going
#
# 355
# 00:16:46,939 --> 00:16:50,120
# to the right the plus plus negative
#
# 356
# 00:16:48,680 --> 00:16:50,870
# tells you up or down you have known this
#
# 357
# 00:16:50,120 --> 00:16:55,009
# so forth
#
# 358
# 00:16:50,870 --> 00:16:57,379
# ok so we're going to go up 1 you offset
#
# 359
# 00:16:55,009 --> 00:16:58,790
# to the right 2 now that we have two
#
# 360
# 00:16:57,379 --> 00:17:03,250
# points we know that two points
#
# 361
# 00:16:58,790 --> 00:17:03,250
# delineates a specific line unique line
#
# 362
# 00:17:03,400 --> 00:17:07,900
# we graph it we make sure we label this
#
# 363
# 00:17:09,850 --> 00:17:12,570
# we're done
#
# 364
# 00:17:13,270 --> 00:17:17,120
# show hands how many will feel okay with
#
# 365
# 00:17:15,620 --> 00:17:19,329
# graphing these lines using slope formula
#
# 366
# 00:17:17,120 --> 00:17:21,500
# and the point slope good day all right
#
# 367
# 00:17:19,329 --> 00:17:24,589
# now there's couple more things we got to
#
# 368
# 00:17:21,500 --> 00:17:27,110
# talk about about lines before we talk
#
# 369
# 00:17:24,589 --> 00:17:39,020
# about parallel and perpendicular we're
#
# 370
# 00:17:27,110 --> 00:17:43,720
# going to do it just second if I told you
#
# 371
# 00:17:39,020 --> 00:17:52,100
# that this was a line y equals to some
#
# 372
# 00:17:43,720 --> 00:17:55,430
# some number C where C wants what type of
#
# 373
# 00:17:52,100 --> 00:17:56,570
# line is that let's just they're all
#
# 374
# 00:17:55,430 --> 00:17:59,050
# straight lines right they're all
#
# 375
# 00:17:56,570 --> 00:18:02,060
# straight lines that's a straight line
#
# 376
# 00:17:59,050 --> 00:18:03,890
# but I think you might mean is is this a
#
# 377
# 00:18:02,060 --> 00:18:06,410
# vertical line or is that a horizontal
#
# 378
# 00:18:03,890 --> 00:18:08,450
# bottom or song line you know the way you
#
# 379
# 00:18:06,410 --> 00:18:10,850
# can tell what variable do you have up
#
# 380
# 00:18:08,450 --> 00:18:13,100
# there that means it's going to cross the
#
# 381
# 00:18:10,850 --> 00:18:15,200
# y-axis whatever variable you have says
#
# 382
# 00:18:13,100 --> 00:18:17,650
# that's the intercept that you have so
#
# 383
# 00:18:15,200 --> 00:18:20,120
# there's no way to have this line
#
# 384
# 00:18:17,650 --> 00:18:21,560
# crossing the y-axis does that make sense
#
# 385
# 00:18:20,120 --> 00:18:22,520
# to you there's no way to do that though
#
# 386
# 00:18:21,560 --> 00:18:24,380
# the way you can do that and have a
#
# 387
# 00:18:22,520 --> 00:18:26,510
# constant line is like this that's a
#
# 388
# 00:18:24,380 --> 00:18:27,380
# horizontal so if you have a y equals
#
# 389
# 00:18:26,510 --> 00:18:29,510
# that's saying you're going to have a
#
# 390
# 00:18:27,380 --> 00:18:31,430
# y-intercept at that number and it's
#
# 391
# 00:18:29,510 --> 00:18:32,900
# going to be horizontal so when y equals
#
# 392
# 00:18:31,430 --> 00:18:35,740
# a constant you're talking about a
#
# 393
# 00:18:32,900 --> 00:18:35,740
# horizontal line
#
# 394
# 00:18:41,700 --> 00:18:49,990
# once the way it can make a vertical line
#
# 395
# 00:18:44,110 --> 00:18:55,620
# just straight up yep if x equals our
#
# 396
# 00:18:49,990 --> 00:18:55,620
# constant we have an x intercept
#
# 397
# 00:19:01,590 --> 00:19:04,820
# that's a vertical line
#
# 398
# 00:19:09,330 --> 00:19:13,139
# we can think about that if you have y
#
# 399
# 00:19:11,639 --> 00:19:14,820
# equals if you try to fit it into this
#
# 400
# 00:19:13,139 --> 00:19:16,590
# formula the slope intercept the point
#
# 401
# 00:19:14,820 --> 00:19:18,330
# slope you've got a slope of 0 right
#
# 402
# 00:19:16,590 --> 00:19:19,379
# there there's no slope there slope is 0
#
# 403
# 00:19:18,330 --> 00:19:21,299
# is going to give you a horizontal line
#
# 404
# 00:19:19,379 --> 00:19:22,889
# if you don't have a Y though that means
#
# 405
# 00:19:21,299 --> 00:19:26,690
# you're going to have a undefined slope
#
# 406
# 00:19:22,889 --> 00:19:26,690
# I mean you're going to be a vertical oh
#
# 407
# 00:19:29,029 --> 00:19:34,639
# yeah let's manipulate one equation we'll
#
# 408
# 00:19:33,119 --> 00:19:36,690
# see if we can put it into
#
# 409
# 00:19:34,639 --> 00:19:38,220
# slope-intercept form we'll talk about
#
# 410
# 00:19:36,690 --> 00:19:39,720
# some parallel perpendicular lines and
#
# 411
# 00:19:38,220 --> 00:19:42,440
# then we'll go onto some trigonometry I
#
# 412
# 00:19:39,720 --> 00:19:44,580
# can tell you're excited excited yeah
#
# 413
# 00:19:42,440 --> 00:19:47,269
# some of your giving me death books right
#
# 414
# 00:19:44,580 --> 00:19:47,269
# now you know that
#
# 415
# 00:20:01,029 --> 00:20:05,469
# right here we have an equation that's
#
# 416
# 00:20:02,799 --> 00:20:07,359
# kind of a standard form of a line it'd
#
# 417
# 00:20:05,469 --> 00:20:09,219
# be standard form if we added three to
#
# 418
# 00:20:07,359 --> 00:20:10,899
# one side and then we'd have we'd have
#
# 419
# 00:20:09,219 --> 00:20:13,419
# the standard form is there a way you can
#
# 420
# 00:20:10,899 --> 00:20:14,589
# put this into slope-intercept go ahead
#
# 421
# 00:20:13,419 --> 00:20:16,209
# and try that for me just go ahead and
#
# 422
# 00:20:14,589 --> 00:20:19,409
# solve for y make up slope-intercept we
#
# 423
# 00:20:16,209 --> 00:20:19,409
# want to make sure you can do it
#
# 424
# 00:20:44,230 --> 00:20:49,970
# what would you do first if you're trying
#
# 425
# 00:20:46,340 --> 00:20:51,140
# to solve that thing for wine now you're
#
# 426
# 00:20:49,970 --> 00:20:55,970
# trying to isolate it what's your first
#
# 427
# 00:20:51,140 --> 00:20:58,520
# step in doing that here you could add
#
# 428
# 00:20:55,970 --> 00:21:01,040
# three then you could subtract 4x and
#
# 429
# 00:20:58,520 --> 00:21:02,720
# then you can divide by two another way
#
# 430
# 00:21:01,040 --> 00:21:04,220
# to do it you could subtract two Y right
#
# 431
# 00:21:02,720 --> 00:21:06,350
# it's probably going to limit it a step
#
# 432
# 00:21:04,220 --> 00:21:13,610
# where you subtract two Y you're going to
#
# 433
# 00:21:06,350 --> 00:21:14,840
# end with 4x minus 3 equals negative 2y
#
# 434
# 00:21:13,610 --> 00:21:15,920
# now typically we don't like to do that
#
# 435
# 00:21:14,840 --> 00:21:18,200
# because we don't want to have a negative
#
# 436
# 00:21:15,920 --> 00:21:19,490
# coefficient for the Y but we just have
#
# 437
# 00:21:18,200 --> 00:21:21,110
# to divide by negative if your goodness
#
# 438
# 00:21:19,490 --> 00:21:23,350
# signs you can do that pretty easily
#
# 439
# 00:21:21,110 --> 00:21:26,390
# how do we get that Y by itself again
#
# 440
# 00:21:23,350 --> 00:21:28,820
# just make sure if you divide you got to
#
# 441
# 00:21:26,390 --> 00:21:30,770
# do it everywhere and you have to have
#
# 442
# 00:21:28,820 --> 00:21:33,380
# the same exact thing and you have to be
#
# 443
# 00:21:30,770 --> 00:21:35,650
# good for signs so 4x over negative 2
#
# 444
# 00:21:33,380 --> 00:21:43,850
# what are you going to get out of that
#
# 445
# 00:21:35,650 --> 00:21:48,890
# how much 2 and then plus or minus how
#
# 446
# 00:21:43,850 --> 00:21:50,390
# much equals sure maybe you write that a
#
# 447
# 00:21:48,890 --> 00:21:53,800
# little bit different skipping in the
#
# 448
# 00:21:50,390 --> 00:21:57,160
# homes you want it y equals negative 2x
#
# 449
# 00:21:53,800 --> 00:22:00,680
# plus 3 halves could you still graph that
#
# 450
# 00:21:57,160 --> 00:22:02,330
# as a matter of fact sometimes it's nice
#
# 451
# 00:22:00,680 --> 00:22:04,070
# to keep it in say I asked you to do it
#
# 452
# 00:22:02,330 --> 00:22:06,050
# in slope-intercept form I want to show
#
# 453
# 00:22:04,070 --> 00:22:10,490
# you this if you have this in standard
#
# 454
# 00:22:06,050 --> 00:22:12,140
# form which would be that have you ever
#
# 455
# 00:22:10,490 --> 00:22:14,120
# learned the cover-up method for graphing
#
# 456
# 00:22:12,140 --> 00:22:15,680
# from standard form you ever seen that
#
# 457
# 00:22:14,120 --> 00:22:19,370
# before if you want to find the
#
# 458
# 00:22:15,680 --> 00:22:20,780
# x-intercept cover up your Y divide by 4
#
# 459
# 00:22:19,370 --> 00:22:25,160
# you know it's going to cross the x axis
#
# 460
# 00:22:20,780 --> 00:22:25,820
# at 4/3 it's easier to graph a fraction
#
# 461
# 00:22:25,160 --> 00:22:28,270
# and going up
#
# 462
# 00:22:25,820 --> 00:22:30,740
# over down over if you want to find the
#
# 463
# 00:22:28,270 --> 00:22:32,570
# y-intercept you cover up the X divided
#
# 464
# 00:22:30,740 --> 00:22:34,480
# by this number two positive two that's
#
# 465
# 00:22:32,570 --> 00:22:36,470
# going to cross the y axis at positive
#
# 466
# 00:22:34,480 --> 00:22:38,150
# three-halves you can graph a line like
#
# 467
# 00:22:36,470 --> 00:22:42,920
# that as well so just a little refresher
#
# 468
# 00:22:38,150 --> 00:22:45,320
# on those Johannah some people do okay so
#
# 469
# 00:22:42,920 --> 00:22:47,360
# far on on our lines still all right
#
# 470
# 00:22:45,320 --> 00:22:49,640
# you'll be awake still this should be
#
# 471
# 00:22:47,360 --> 00:22:50,750
# review this is review for you I know
#
# 472
# 00:22:49,640 --> 00:22:52,250
# some of you are thinking where's the
#
# 473
# 00:22:50,750 --> 00:22:53,450
# calculus just wait for it
#
# 474
# 00:22:52,250 --> 00:22:55,610
# all right the calculus is going to come
#
# 475
# 00:22:53,450 --> 00:22:57,560
# whether you want to or not just hang on
#
# 476
# 00:22:55,610 --> 00:22:59,840
# for a second enjoy the nice slow stuff
#
# 477
# 00:22:57,560 --> 00:23:01,880
# but really absorb this in here if you're
#
# 478
# 00:22:59,840 --> 00:23:04,600
# a little rusty on it what do you know
#
# 479
# 00:23:01,880 --> 00:23:06,860
# about parallel lines
#
# 480
# 00:23:04,600 --> 00:23:08,540
# that's extra definition did you hear
#
# 481
# 00:23:06,860 --> 00:23:09,830
# them over there we have the same exact
#
# 482
# 00:23:08,540 --> 00:23:11,570
# slope that means we have parallel lines
#
# 483
# 00:23:09,830 --> 00:23:13,490
# it's kind of like climbing stairs right
#
# 484
# 00:23:11,570 --> 00:23:14,870
# the way stairs work is they're parallel
#
# 485
# 00:23:13,490 --> 00:23:17,060
# that means you're going up and over the
#
# 486
# 00:23:14,870 --> 00:23:19,040
# same rate otherwise these stairs over
#
# 487
# 00:23:17,060 --> 00:23:20,900
# here if you're if your stairs didn't go
#
# 488
# 00:23:19,040 --> 00:23:23,030
# up and over you give me like this you're
#
# 489
# 00:23:20,900 --> 00:23:24,830
# like oh these are nice you feed to my
#
# 490
# 00:23:23,030 --> 00:23:26,720
# son of a gun you know if they were
#
# 491
# 00:23:24,830 --> 00:23:27,740
# different slopes you they intersect
#
# 492
# 00:23:26,720 --> 00:23:29,420
# somewhere we don't want that to happen
#
# 493
# 00:23:27,740 --> 00:23:31,400
# for stairs we don't want that to happen
#
# 494
# 00:23:29,420 --> 00:23:32,450
# for parallel lines so we talk about
#
# 495
# 00:23:31,400 --> 00:23:36,250
# parallel lines when we're talking about
#
# 496
# 00:23:32,450 --> 00:23:36,250
# our lines that have the same exact slope
#
# 497
# 00:23:54,000 --> 00:23:56,060
# you
#
# 498
# 00:24:05,550 --> 00:24:10,890
# do perpendicular lines have the same
#
# 499
# 00:24:07,140 --> 00:24:13,050
# slope no no no actually perpendicular
#
# 500
# 00:24:10,890 --> 00:24:14,790
# lines meet at a very specific angle what
#
# 501
# 00:24:13,050 --> 00:24:16,950
# angle do perpendicular lines meet at
#
# 502
# 00:24:14,790 --> 00:24:18,000
# right so if one lines like this the
#
# 503
# 00:24:16,950 --> 00:24:20,160
# other lines got to be like that right
#
# 504
# 00:24:18,000 --> 00:24:21,540
# means if one slopes positive those
#
# 505
# 00:24:20,160 --> 00:24:23,730
# slopes negative so we know that's going
#
# 506
# 00:24:21,540 --> 00:24:25,830
# to come into play also there's a it's
#
# 507
# 00:24:23,730 --> 00:24:27,210
# not just a negative slope that's going
#
# 508
# 00:24:25,830 --> 00:24:29,160
# to be something like this right that's
#
# 509
# 00:24:27,210 --> 00:24:31,260
# like an across a 90 degrees we want to
#
# 510
# 00:24:29,160 --> 00:24:33,000
# make it actually just a little kicked
#
# 511
# 00:24:31,260 --> 00:24:34,500
# over how do I make it so it meets
#
# 512
# 00:24:33,000 --> 00:24:37,800
# exactly the 90 degrees is not only
#
# 513
# 00:24:34,500 --> 00:24:40,980
# negative but also a very good W so
#
# 514
# 00:24:37,800 --> 00:24:43,380
# reciprocal so perpendicular lines are
#
# 515
# 00:24:40,980 --> 00:24:46,940
# lines or chats or lines where the slopes
#
# 516
# 00:24:43,380 --> 00:24:46,940
# are negative reciprocals of each other
#
# 517
# 00:25:16,190 --> 00:25:19,190
# okay
#
# 518
# 00:25:22,259 --> 00:25:27,789
# let's basic question if I give you an
#
# 519
# 00:25:24,580 --> 00:25:30,999
# equation can you find a line that's
#
# 520
# 00:25:27,789 --> 00:25:33,009
# parallel and/or perpendicular I'm sorry
#
# 521
# 00:25:30,999 --> 00:25:34,960
# or perpendicular to a given equation can
#
# 522
# 00:25:33,009 --> 00:25:37,960
# you guys do that let's try that on real
#
# 523
# 00:25:34,960 --> 00:25:39,489
# quick that will be our last little timid
#
# 524
# 00:25:37,960 --> 00:25:43,629
# review problem hopefully these have been
#
# 525
# 00:25:39,489 --> 00:25:45,909
# timid for you and they've made it 30
#
# 526
# 00:25:43,629 --> 00:25:49,539
# minutes and we haven't we're going to
#
# 527
# 00:25:45,909 --> 00:25:59,559
# get to some training just a bit you get
#
# 528
# 00:25:49,539 --> 00:26:00,849
# up so let me say that I want to find the
#
# 529
# 00:25:59,559 --> 00:26:03,419
# equation of the line that passes through
#
# 530
# 00:26:00,849 --> 00:26:03,419
# this point
#
# 531
# 00:26:13,330 --> 00:26:16,860
# and parallel to
#
# 532
# 00:26:23,260 --> 00:26:26,260
# this
#
# 533
# 00:26:33,679 --> 00:26:38,759
# find the equation passing through a set
#
# 534
# 00:26:36,090 --> 00:26:41,100
# point and parallel to a given equation
#
# 535
# 00:26:38,759 --> 00:26:43,789
# what's the two things you need for sure
#
# 536
# 00:26:41,100 --> 00:26:46,919
# it ought to make the equation of a line
#
# 537
# 00:26:43,789 --> 00:26:50,549
# slope and what no dew point do I have a
#
# 538
# 00:26:46,919 --> 00:26:51,419
# point cool do have a slope do have a
#
# 539
# 00:26:50,549 --> 00:26:53,879
# slope right now
#
# 540
# 00:26:51,419 --> 00:26:56,220
# not yet I got to work on it but could
#
# 541
# 00:26:53,879 --> 00:26:57,299
# you find that slope let's find the slope
#
# 542
# 00:26:56,220 --> 00:26:58,919
# go ahead and do it on your own real
#
# 543
# 00:26:57,299 --> 00:27:01,759
# quick in about five seconds you should
#
# 544
# 00:26:58,919 --> 00:27:01,759
# be pretty good at this
#
# 545
# 00:27:11,660 --> 00:27:17,590
# is the slope negative to know what am I
#
# 546
# 00:27:15,530 --> 00:27:17,590
# missing
#
# 547
# 00:27:22,540 --> 00:27:26,150
# as a reason we talk about
#
# 548
# 00:27:24,260 --> 00:27:32,300
# slope-intercept right and to find that
#
# 549
# 00:27:26,150 --> 00:27:34,610
# slope very easily your slopes negative
#
# 550
# 00:27:32,300 --> 00:27:36,470
# two thirds now what I'm asking for is
#
# 551
# 00:27:34,610 --> 00:27:40,040
# the equation of line that's parallel to
#
# 552
# 00:27:36,470 --> 00:27:40,700
# that line but now goes through that
#
# 553
# 00:27:40,040 --> 00:27:42,830
# point
#
# 554
# 00:27:40,700 --> 00:27:45,230
# so what's slope my going to use if I
#
# 555
# 00:27:42,830 --> 00:27:49,100
# want to find the the parallel line of
#
# 556
# 00:27:45,230 --> 00:27:52,700
# this amuse three halves but won't the
#
# 557
# 00:27:49,100 --> 00:27:54,050
# parallel is this all parallel lines have
#
# 558
# 00:27:52,700 --> 00:27:56,120
# the same slope so what we're going right
#
# 559
# 00:27:54,050 --> 00:28:00,980
# down we're going to find our slope we
#
# 560
# 00:27:56,120 --> 00:28:02,090
# want the pair little slope so we're
#
# 561
# 00:28:00,980 --> 00:28:03,350
# going to write down the parallel slope
#
# 562
# 00:28:02,090 --> 00:28:05,900
# if it's parallel it's going to be
#
# 563
# 00:28:03,350 --> 00:28:09,250
# exactly the same we know that our M is
#
# 564
# 00:28:05,900 --> 00:28:14,810
# going to be negative 2/3
#
# 565
# 00:28:09,250 --> 00:28:19,220
# now what point do we use what point do
#
# 566
# 00:28:14,810 --> 00:28:21,800
# we use speak up for these does this Ford
#
# 567
# 00:28:19,220 --> 00:28:24,410
# have anything to do with this problem
#
# 568
# 00:28:21,800 --> 00:28:26,420
# actually all we cared about was finding
#
# 569
# 00:28:24,410 --> 00:28:30,770
# stuff once we have the slope and we've
#
# 570
# 00:28:26,420 --> 00:28:31,910
# already identified a point wow we can
#
# 571
# 00:28:30,770 --> 00:28:35,740
# just plug that into our point-slope
#
# 572
# 00:28:31,910 --> 00:28:35,740
# formula find the quays of our line
#
# 573
# 00:28:42,480 --> 00:28:54,080
# so we'll do y minus 7 equals negative
#
# 574
# 00:28:48,320 --> 00:28:54,080
# 2/3 X minus 6
#
# 575
# 00:28:56,960 --> 00:29:02,010
# quick quick show of hands how many will
#
# 576
# 00:28:59,220 --> 00:29:03,240
# feel ok solving for slope give me a head
#
# 577
# 00:29:02,010 --> 00:29:05,070
# not if you understand that the slope
#
# 578
# 00:29:03,240 --> 00:29:06,870
# we're supposed to use is still negative
#
# 579
# 00:29:05,070 --> 00:29:09,360
# 2/3 because we want to find a parallel
#
# 580
# 00:29:06,870 --> 00:29:11,640
# do you see with a 6 and 7 or coming from
#
# 581
# 00:29:09,360 --> 00:29:14,460
# good deal can you work that out and make
#
# 582
# 00:29:11,640 --> 00:29:16,680
# that slope intercept for me ok let's do
#
# 583
# 00:29:14,460 --> 00:29:18,360
# that together I know that Y minus 7
#
# 584
# 00:29:16,680 --> 00:29:19,050
# that's can stay there on the right-hand
#
# 585
# 00:29:18,360 --> 00:29:22,980
# side
#
# 586
# 00:29:19,050 --> 00:29:25,850
# tell me what I'm gonna get and then plus
#
# 587
# 00:29:22,980 --> 00:29:32,550
# or minus what you think plus how much
#
# 588
# 00:29:25,850 --> 00:29:34,950
# good final step if we add set 4 because
#
# 589
# 00:29:32,550 --> 00:29:36,570
# we have 2/3 times 6 2/3 times 60 and
#
# 590
# 00:29:34,950 --> 00:29:40,850
# some of the fractions or your 12 thirds
#
# 591
# 00:29:36,570 --> 00:29:40,850
# that's 4 add our 7 to both sides
#
# 592
# 00:29:44,890 --> 00:29:48,160
# and we're done
#
# 593
# 00:29:49,820 --> 00:29:54,980
# what if I change the problem and instead
#
# 594
# 00:29:52,790 --> 00:29:56,680
# of having parallel I asked you to do
#
# 595
# 00:29:54,980 --> 00:29:58,910
# perpendicular could you still do it
#
# 596
# 00:29:56,680 --> 00:30:00,020
# let's talk about the only changes that
#
# 597
# 00:29:58,910 --> 00:30:01,040
# would occur up here okay I'm not gonna
#
# 598
# 00:30:00,020 --> 00:30:02,630
# change the whole progress I want to walk
#
# 599
# 00:30:01,040 --> 00:30:06,100
# you through it here I'm talking about
#
# 600
# 00:30:02,630 --> 00:30:08,990
# perpendicular with this process change
#
# 601
# 00:30:06,100 --> 00:30:11,900
# would this change what's that going to
#
# 602
# 00:30:08,990 --> 00:30:13,520
# become okay so this is becoming three
#
# 603
# 00:30:11,900 --> 00:30:16,300
# now so here now we're talking about
#
# 604
# 00:30:13,520 --> 00:30:16,300
# perpendicular
#
# 605
# 00:30:23,280 --> 00:30:28,140
# with the seven and the six change now
#
# 606
# 00:30:26,250 --> 00:30:30,030
# we're just talking about slope about
#
# 607
# 00:30:28,140 --> 00:30:35,670
# this is parallel perpendicular only has
#
# 608
# 00:30:30,030 --> 00:30:41,130
# to do with slopes this would change to
#
# 609
# 00:30:35,670 --> 00:30:45,720
# our three halves this would change to
#
# 610
# 00:30:41,130 --> 00:30:48,360
# our three halves X and B - how much Y
#
# 611
# 00:30:45,720 --> 00:30:56,610
# it's nine if we added seven to both
#
# 612
# 00:30:48,360 --> 00:30:59,220
# sides here we get three halves X minus
#
# 613
# 00:30:56,610 --> 00:31:01,950
# two so we find both the parallel and the
#
# 614
# 00:30:59,220 --> 00:31:04,770
# perpendicular slope do you feel okay
#
# 615
# 00:31:01,950 --> 00:31:06,480
# about our basic lines so far would you
#
# 616
# 00:31:04,770 --> 00:31:08,130
# like to learn a little bit about angles
#
# 617
# 00:31:06,480 --> 00:31:11,130
# of inclination and use a little bit of
#
# 618
# 00:31:08,130 --> 00:31:13,560
# trigonometry here and you're like no not
#
# 619
# 00:31:11,130 --> 00:31:14,790
# really do that you do anyway let's talk
#
# 620
# 00:31:13,560 --> 00:31:19,380
# about angles inclination we're going to
#
# 621
# 00:31:14,790 --> 00:31:21,500
# use it at some point are there any
#
# 622
# 00:31:19,380 --> 00:31:24,950
# questions before erase any of this stuff
#
# 623
# 00:31:21,500 --> 00:31:26,940
# are you sure are we having fun yet
#
# 624
# 00:31:24,950 --> 00:31:29,010
# once you rather be in here that out
#
# 625
# 00:31:26,940 --> 00:31:32,750
# there in the rain some of you're like no
#
# 626
# 00:31:29,010 --> 00:31:32,750
# I'd rather be in the rain right now
#
# 627
# 00:31:33,350 --> 00:31:37,500
# just lighten II just lied say yes this
#
# 628
# 00:31:35,880 --> 00:31:45,150
# is awesome Leonard I love this class
#
# 629
# 00:31:37,500 --> 00:31:46,500
# you're the best thanks guys beginning if
#
# 630
# 00:31:45,150 --> 00:31:48,030
# you did that I would just watch this
#
# 631
# 00:31:46,500 --> 00:31:49,500
# video over and over again and have you
#
# 632
# 00:31:48,030 --> 00:31:51,330
# go thanks Leonard you're the best
#
# 633
# 00:31:49,500 --> 00:31:52,530
# yeah thanks Leonard you're the best yeah
#
# 634
# 00:31:51,330 --> 00:31:56,700
# thanks Leonard you're the best
#
# 635
# 00:31:52,530 --> 00:32:00,040
# yeah yeah I do look with my workout
#
# 636
# 00:31:56,700 --> 00:32:13,780
# thanks Larry you're the best damn damn
#
# 637
# 00:32:00,040 --> 00:32:17,320
# so cool all right Oliver Oh my angle of
#
# 638
# 00:32:13,780 --> 00:32:19,480
# inclination let's talk about how we can
#
# 639
# 00:32:17,320 --> 00:32:23,320
# use angle of inclination and related to
#
# 640
# 00:32:19,480 --> 00:32:28,480
# a slope we're going to start with some
#
# 641
# 00:32:23,320 --> 00:32:30,130
# line random line when I talk about the
#
# 642
# 00:32:28,480 --> 00:32:33,070
# angle of inclination what we talk about
#
# 643
# 00:32:30,130 --> 00:32:35,400
# is the angle that any line makes with
#
# 644
# 00:32:33,070 --> 00:32:37,750
# the x-axis so the angle of inclination
#
# 645
# 00:32:35,400 --> 00:32:39,820
# these actually be the same angle taking
#
# 646
# 00:32:37,750 --> 00:32:41,260
# geometry you know those ones are the
#
# 647
# 00:32:39,820 --> 00:32:46,660
# same we're really just talking about
#
# 648
# 00:32:41,260 --> 00:32:50,950
# this one call it theta we want to find
#
# 649
# 00:32:46,660 --> 00:32:56,650
# some way to represent this line as
#
# 650
# 00:32:50,950 --> 00:33:00,460
# having that angle if we think about the
#
# 651
# 00:32:56,650 --> 00:33:02,440
# X and the y-axis notice that this we
#
# 652
# 00:33:00,460 --> 00:33:04,390
# could represent as a change in X
#
# 653
# 00:33:02,440 --> 00:33:06,460
# you guys have seen that that terminology
#
# 654
# 00:33:04,390 --> 00:33:12,340
# for the Delta X change in X and this
#
# 655
# 00:33:06,460 --> 00:33:14,080
# would be well the change in Y now think
#
# 656
# 00:33:12,340 --> 00:33:16,240
# back to your trig days is just basic
#
# 657
# 00:33:14,080 --> 00:33:19,480
# trigonometry is there a trig function
#
# 658
# 00:33:16,240 --> 00:33:21,850
# that read that that relates this angle
#
# 659
# 00:33:19,480 --> 00:33:26,280
# and these two specific sides remember
#
# 660
# 00:33:21,850 --> 00:33:28,720
# this would be a 90-degree what does that
#
# 661
# 00:33:26,280 --> 00:33:32,020
# what's it this is a triangle which it is
#
# 662
# 00:33:28,720 --> 00:33:34,870
# what's this cycle that's hypotenuse
#
# 663
# 00:33:32,020 --> 00:33:37,140
# what's this one according to this angle
#
# 664
# 00:33:34,870 --> 00:33:41,080
# that's the good and this one is the
#
# 665
# 00:33:37,140 --> 00:33:44,230
# which one relates adjacent and opposite
#
# 666
# 00:33:41,080 --> 00:33:47,110
# engine not science I would be opposite
#
# 667
# 00:33:44,230 --> 00:33:48,610
# over hypotenuse and tangent does or
#
# 668
# 00:33:47,110 --> 00:33:51,370
# cotangent we don't do a cotangent
#
# 669
# 00:33:48,610 --> 00:33:52,660
# cotangent adjacent over opposite we want
#
# 670
# 00:33:51,370 --> 00:33:59,050
# ...
# 01:15:48,139 --> 01:15:53,179
# want to use okay good they have to be
#
# 1486
# 01:15:52,010 --> 01:15:54,889
# negative though cursor to the left to
#
# 1487
# 01:15:53,179 --> 01:16:00,020
# zero so negative point five that'll work
#
# 1488
# 01:15:54,889 --> 01:16:02,449
# and negative point zero one and negative
#
# 1489
# 01:16:00,020 --> 01:16:07,159
# point zero zero one so let's use those
#
# 1490
# 01:16:02,449 --> 01:16:11,900
# numbers again left side people do left
#
# 1491
# 01:16:07,159 --> 01:16:13,219
# side right side people do right side it
#
# 1492
# 01:16:11,900 --> 01:16:15,369
# should be a little bit easier to plug in
#
# 1493
# 01:16:13,219 --> 01:16:15,369
# yeah
#
# 1494
# 01:16:26,680 --> 01:16:30,770
# by the way this is going a little bit
#
# 1495
# 01:16:29,000 --> 01:16:31,940
# out of the scope of this section at this
#
# 1496
# 01:16:30,770 --> 01:16:33,380
# point we're talking about something a
#
# 1497
# 01:16:31,940 --> 01:16:35,300
# little ahead of time cuz it's
#
# 1498
# 01:16:33,380 --> 01:16:37,550
# interesting to me so we're covering this
#
# 1499
# 01:16:35,300 --> 01:16:39,410
# right now it will come back at us
#
# 1500
# 01:16:37,550 --> 01:16:41,780
# later on right but I'd like to make sure
#
# 1501
# 01:16:39,410 --> 01:16:47,630
# you see it in limits at least once or
#
# 1502
# 01:16:41,780 --> 01:16:50,270
# twice before we get to that section so
#
# 1503
# 01:16:47,630 --> 01:16:52,750
# if you take one divided by 0.5 I'm
#
# 1504
# 01:16:50,270 --> 01:16:55,610
# hoping that you got to did you get to
#
# 1505
# 01:16:52,750 --> 01:16:57,080
# and over here you probably got well I'm
#
# 1506
# 01:16:55,610 --> 01:17:03,950
# gonna be a genius about that negative 2
#
# 1507
# 01:16:57,080 --> 01:17:06,980
# you get nave - no ok good
#
# 1508
# 01:17:03,950 --> 01:17:08,030
# who scared myself for a second so - and
#
# 1509
# 01:17:06,980 --> 01:17:10,910
# NATO - very good
#
# 1510
# 01:17:08,030 --> 01:17:13,040
# now how about point zero one if you
#
# 1511
# 01:17:10,910 --> 01:17:14,960
# divide one by point zero one you should
#
# 1512
# 01:17:13,040 --> 01:17:22,520
# get the C move the decimal place you
#
# 1513
# 01:17:14,960 --> 01:17:25,700
# should get unfunded and I'm gonna hope
#
# 1514
# 01:17:22,520 --> 01:17:27,830
# this is negative 100 yes if you divide
#
# 1515
# 01:17:25,700 --> 01:17:29,510
# by point zero zero one that's let's say
#
# 1516
# 01:17:27,830 --> 01:17:31,460
# one to three decimal places you're just
#
# 1517
# 01:17:29,510 --> 01:17:38,720
# fighting one by decimal places there and
#
# 1518
# 01:17:31,460 --> 01:17:40,310
# even one that should be let's do a
#
# 1519
# 01:17:38,720 --> 01:17:43,640
# little critical thinking here all right
#
# 1520
# 01:17:40,310 --> 01:17:45,320
# first question is is this number getting
#
# 1521
# 01:17:43,640 --> 01:17:47,780
# bigger or smaller as you are approaching
#
# 1522
# 01:17:45,320 --> 01:17:52,520
# zero from the writer is it ever going to
#
# 1523
# 01:17:47,780 --> 01:17:53,780
# stop getting bigger 1/3 0 0 0 1 is gonna
#
# 1524
# 01:17:52,520 --> 01:17:57,950
# be really really really really really
#
# 1525
# 01:17:53,780 --> 01:18:00,350
# big right and cb+ how about this way is
#
# 1526
# 01:17:57,950 --> 01:18:01,550
# it getting bigger or smaller way smaller
#
# 1527
# 01:18:00,350 --> 01:18:02,750
# and it's never going to stop getting
#
# 1528
# 01:18:01,550 --> 01:18:04,670
# smaller it's not going to a certain
#
# 1529
# 01:18:02,750 --> 01:18:08,150
# number now first the second question is
#
# 1530
# 01:18:04,670 --> 01:18:11,330
# does the limit exist are they going to
#
# 1531
# 01:18:08,150 --> 01:18:13,190
# the same exact number no in fact as
#
# 1532
# 01:18:11,330 --> 01:18:14,360
# we're going from the right where would
#
# 1533
# 01:18:13,190 --> 01:18:16,610
# you say this is going because if you
#
# 1534
# 01:18:14,360 --> 01:18:18,909
# draw the picture it's going like like
#
# 1535
# 01:18:16,610 --> 01:18:21,010
# that it's going to where
#
# 1536
# 01:18:18,909 --> 01:18:22,300
# finiti if you divide by smaller and
#
# 1537
# 01:18:21,010 --> 01:18:24,130
# smaller numbers that are approaching
#
# 1538
# 01:18:22,300 --> 01:18:26,050
# zero keep divided by point zero zero
#
# 1539
# 01:18:24,130 --> 01:18:27,880
# zero zero zero forever in the little one
#
# 1540
# 01:18:26,050 --> 01:18:29,679
# you're going to get really really huge
#
# 1541
# 01:18:27,880 --> 01:18:32,080
# numbers right and you can keep getting
#
# 1542
# 01:18:29,679 --> 01:18:36,639
# smaller and smaller still so what we
#
# 1543
# 01:18:32,080 --> 01:18:39,550
# would say is the limit as X approaches 0
#
# 1544
# 01:18:36,639 --> 01:18:45,489
# from the right of our function which is
#
# 1545
# 01:18:39,550 --> 01:18:46,540
# 1 over X is positive and thin and you
#
# 1546
# 01:18:45,489 --> 01:18:48,850
# double you technically don't have to put
#
# 1547
# 01:18:46,540 --> 01:18:50,590
# the plus cuz infinity without that plus
#
# 1548
# 01:18:48,850 --> 01:18:53,010
# still meets positive and I want to show
#
# 1549
# 01:18:50,590 --> 01:18:53,010
# the difference
#
# 1550
# 01:18:56,500 --> 01:19:03,670
# limit as you approach I'm sorry as X
#
# 1551
# 01:19:00,280 --> 01:19:06,930
# approaches zero from the left here's
#
# 1552
# 01:19:03,670 --> 01:19:08,680
# what would you say that would be is
#
# 1553
# 01:19:06,930 --> 01:19:11,170
# negative fitting the same thing as
#
# 1554
# 01:19:08,680 --> 01:19:13,690
# positive infinity so limit clearly
#
# 1555
# 01:19:11,170 --> 01:19:16,840
# doesn't exist and cut you can see this
#
# 1556
# 01:19:13,690 --> 01:19:18,850
# from the graph if you graph 1 over X
#
# 1557
# 01:19:16,840 --> 01:19:26,710
# your calculator if you draft mountain
#
# 1558
# 01:19:18,850 --> 01:19:29,949
# like this that's it you can see as we
#
# 1559
# 01:19:26,710 --> 01:19:32,770
# get towards 0 its skyrocketing as we get
#
# 1560
# 01:19:29,949 --> 01:19:35,290
# towards 0 it's really going into a this
#
# 1561
# 01:19:32,770 --> 01:19:37,090
# right so it's it's not going to the same
#
# 1562
# 01:19:35,290 --> 01:19:44,140
# thing but this leads us to a couple
#
# 1563
# 01:19:37,090 --> 01:19:46,150
# ideas whenever we have a limit I'll
#
# 1564
# 01:19:44,140 --> 01:19:54,280
# write this up for you if you have a
#
# 1565
# 01:19:46,150 --> 01:19:57,489
# limit as X approaches a from either the
#
# 1566
# 01:19:54,280 --> 01:20:00,190
# right or the left of some function and
#
# 1567
# 01:19:57,489 --> 01:20:06,340
# you figure out that it's positive or
#
# 1568
# 01:20:00,190 --> 01:20:08,710
# negative infinity so again if you are
#
# 1569
# 01:20:06,340 --> 01:20:10,510
# approaching a number right from either
#
# 1570
# 01:20:08,710 --> 01:20:12,160
# the right or from the left and it's
#
# 1571
# 01:20:10,510 --> 01:20:14,770
# going to infinity either positive or
#
# 1572
# 01:20:12,160 --> 01:20:18,060
# negative what that does for you is it
#
# 1573
# 01:20:14,770 --> 01:20:20,710
# gives you an what's this thing called
#
# 1574
# 01:20:18,060 --> 01:20:22,600
# get your NASA total gives you a
#
# 1575
# 01:20:20,710 --> 01:20:24,969
# something because you say okay if we're
#
# 1576
# 01:20:22,600 --> 01:20:27,280
# going towards infinity as we reach as as
#
# 1577
# 01:20:24,969 --> 01:20:29,110
# if my y-values going to infinity as my x
#
# 1578
# 01:20:27,280 --> 01:20:31,540
# value reaches a number that means I have
#
# 1579
# 01:20:29,110 --> 01:20:33,370
# to be shooting up if my Y values go to
#
# 1580
# 01:20:31,540 --> 01:20:35,020
# negative a as I reach a certain number
#
# 1581
# 01:20:33,370 --> 01:20:37,239
# that means that have to be shooting down
#
# 1582
# 01:20:35,020 --> 01:20:39,550
# so one of those cases it's going to be
#
# 1583
# 01:20:37,239 --> 01:20:40,989
# some sort of asymptotes you're never
#
# 1584
# 01:20:39,550 --> 01:20:44,680
# going to actually get to that point you
#
# 1585
# 01:20:40,989 --> 01:20:47,560
# can okay so there are really four cases
#
# 1586
# 01:20:44,680 --> 01:20:49,900
# I'll draw them over there let me see
#
# 1587
# 01:20:47,560 --> 01:20:53,130
# them for chasm of asymptotes and the
#
# 1588
# 01:20:49,900 --> 01:20:53,130
# relationships to their limits
#
# 1589
# 01:21:34,739 --> 01:21:38,670
# so the one case is what happens if we
#
# 1590
# 01:21:37,350 --> 01:21:39,690
# approach a from the right and we're
#
# 1591
# 01:21:38,670 --> 01:21:43,680
# going to positive infinity
#
# 1592
# 01:21:39,690 --> 01:21:45,480
# another case would be what happens if we
#
# 1593
# 01:21:43,680 --> 01:21:47,900
# approach a from the right and we go to
#
# 1594
# 01:21:45,480 --> 01:21:47,900
# negative infinity
#
# 1595
# 01:21:54,070 --> 01:21:59,750
# another case would be well what would
#
# 1596
# 01:21:56,180 --> 01:22:02,660
# happen if we went we did the both rights
#
# 1597
# 01:21:59,750 --> 01:22:06,400
# right for right if we went to a from the
#
# 1598
# 01:22:02,660 --> 01:22:06,400
# left and with the positive infinity or
#
# 1599
# 01:22:07,270 --> 01:22:17,600
# what would happen if we went to a from
#
# 1600
# 01:22:13,460 --> 01:22:19,280
# the left and it gave us negative
#
# 1601
# 01:22:17,600 --> 01:22:25,360
# infinity which agree those are all four
#
# 1602
# 01:22:19,280 --> 01:22:28,390
# permutations all four cases of this in
#
# 1603
# 01:22:25,360 --> 01:22:30,740
# either case we just talked about this if
#
# 1604
# 01:22:28,390 --> 01:22:33,590
# your function is going to positive
#
# 1605
# 01:22:30,740 --> 01:22:34,850
# infinity when X is going to a from left
#
# 1606
# 01:22:33,590 --> 01:22:37,100
# or right you're going to have an
#
# 1607
# 01:22:34,850 --> 01:22:39,890
# asymptote so every one of these is going
#
# 1608
# 01:22:37,100 --> 01:22:42,850
# to be an asymptote well it's the worst
#
# 1609
# 01:22:39,890 --> 01:22:42,850
# asymptote I've ever drawn
#
# 1610
# 01:22:48,810 --> 01:22:51,560
# second
#
# 1611
# 01:22:55,690 --> 01:22:58,690
# perfect
#
# 1612
# 01:23:01,660 --> 01:23:04,160
# it's kind of diagnose what these things
#
# 1613
# 01:23:03,650 --> 01:23:05,840
# would you
#
# 1614
# 01:23:04,160 --> 01:23:07,970
# I want you really think of what these
#
# 1615
# 01:23:05,840 --> 01:23:08,570
# limits should do to our art function
#
# 1616
# 01:23:07,970 --> 01:23:11,030
# your okay
#
# 1617
# 01:23:08,570 --> 01:23:15,050
# now if I say X is approaching aid from
#
# 1618
# 01:23:11,030 --> 01:23:18,590
# the right chefs are here or start this
#
# 1619
# 01:23:15,050 --> 01:23:22,490
# way am I going on this way option 1 or
#
# 1620
# 01:23:18,590 --> 01:23:24,050
# this way option 2 function 1 so if the
#
# 1621
# 01:23:22,490 --> 01:23:26,780
# function is approaching a from the right
#
# 1622
# 01:23:24,050 --> 01:23:30,040
# and it goes to positive infinity should
#
# 1623
# 01:23:26,780 --> 01:23:32,930
# I be going up or should I be going down
#
# 1624
# 01:23:30,040 --> 01:23:35,270
# so this would be this type of graph it
#
# 1625
# 01:23:32,930 --> 01:23:37,550
# should do whatever it wants over here no
#
# 1626
# 01:23:35,270 --> 01:23:41,870
# problem but when it gets to here it
#
# 1627
# 01:23:37,550 --> 01:23:44,180
# shoots up this is not going to be this
#
# 1628
# 01:23:41,870 --> 01:23:46,250
# isn't going to be told by our limit as
#
# 1629
# 01:23:44,180 --> 01:23:48,110
# we approach a rightist that hasn't a
#
# 1630
# 01:23:46,250 --> 01:23:50,180
# clue it's what happens as we get close
#
# 1631
# 01:23:48,110 --> 01:23:52,310
# to a it's going to be going towards
#
# 1632
# 01:23:50,180 --> 01:23:53,870
# positive let's let's start with this one
#
# 1633
# 01:23:52,310 --> 01:23:55,730
# now I know we were just coming from the
#
# 1634
# 01:23:53,870 --> 01:23:57,620
# right hand side this one's going to be
#
# 1635
# 01:23:55,730 --> 01:24:00,140
# going well not up not positive phase we
#
# 1636
# 01:23:57,620 --> 01:24:04,210
# going down they infinity whatever you
#
# 1637
# 01:24:00,140 --> 01:24:08,380
# want over here but it's going to drop
#
# 1638
# 01:24:04,210 --> 01:24:08,380
# it's going to be at some product to that
#
# 1639
# 01:24:13,570 --> 01:24:18,530
# how about this one can you picture what
#
# 1640
# 01:24:15,770 --> 01:24:19,610
# that one does in your then already draw
#
# 1641
# 01:24:18,530 --> 01:24:20,540
# a graph if you want you right now you
#
# 1642
# 01:24:19,610 --> 01:24:22,760
# should be able to draw something with
#
# 1643
# 01:24:20,540 --> 01:24:25,760
# that are we going option one from the
#
# 1644
# 01:24:22,760 --> 01:24:27,739
# right or option two from the left from
#
# 1645
# 01:24:25,760 --> 01:24:32,540
# the left and should we be going up or
#
# 1646
# 01:24:27,739 --> 01:24:34,900
# down which one let's go to plus infinity
#
# 1647
# 01:24:32,540 --> 01:24:34,900
# up or down
#
# 1648
# 01:24:40,650 --> 01:24:45,310
# lastly the only case we have left is
#
# 1649
# 01:24:42,940 --> 01:24:52,140
# from the left going down to negative
#
# 1650
# 01:24:45,310 --> 01:24:52,140
# infinity looks something like that
#
# 1651
# 01:24:55,219 --> 01:24:58,570
# would you raise your hand if you feel
#
# 1652
# 01:24:56,630 --> 01:25:01,280
# okay with what talk about so far today
#
# 1653
# 01:24:58,570 --> 01:25:02,900
# all right that takes care of kind of our
#
# 1654
# 01:25:01,280 --> 01:25:04,880
# introduction to limits but we talked a
#
# 1655
# 01:25:02,900 --> 01:25:05,900
# little bit about that now but the rest
#
# 1656
# 01:25:04,880 --> 01:25:07,969
# of our day I'm going to teach you how to
#
# 1657
# 01:25:05,900 --> 01:25:09,829
# compute limits because if notice this
#
# 1658
# 01:25:07,969 --> 01:25:11,030
# this isn't all that fun I'm going to
#
# 1659
# 01:25:09,829 --> 01:25:12,860
# show you some better ways on how to do
#
# 1660
# 01:25:11,030 --> 01:25:20,570
# that would you like to learn that any
#
# 1661
# 01:25:12,860 --> 01:25:22,999
# questions before you want the limit
#
# 1662
# 01:25:20,570 --> 01:25:24,650
# would exist yes it would so if we have a
#
# 1663
# 01:25:22,999 --> 01:25:26,059
# one side limit this way and one side
#
# 1664
# 01:25:24,650 --> 01:25:28,010
# them in that way they both go to pause
#
# 1665
# 01:25:26,059 --> 01:25:30,079
# and fin yeah sure we'd say the limit is
#
# 1666
# 01:25:28,010 --> 01:25:33,499
# positive in because it goes from both
#
# 1667
# 01:25:30,079 --> 01:25:36,289
# sides or if a limit is going both Megan
#
# 1668
# 01:25:33,499 --> 01:25:37,400
# infinity that would exist so let's see
#
# 1669
# 01:25:36,289 --> 01:25:41,479
# this way
#
# 1670
# 01:25:37,400 --> 01:25:43,369
# yes this way yes this way no this way
#
# 1671
# 01:25:41,479 --> 01:25:51,610
# now that takes practice to do that by
#
# 1672
# 01:25:43,369 --> 01:25:53,829
# the way yeah
#
# 1673
# 01:25:51,610 --> 01:25:56,440
# it's approaching from the right it
#
# 1674
# 01:25:53,829 --> 01:25:59,800
# should be a perfect on the left this one
#
# 1675
# 01:25:56,440 --> 01:26:01,360
# never one above this one this is
#
# 1676
# 01:25:59,800 --> 01:26:06,099
# approaching from the right going to
#
# 1677
# 01:26:01,360 --> 01:26:07,989
# negativity oh I feel a plus on everybody
#
# 1678
# 01:26:06,099 --> 01:26:11,250
# yeah you know what let me write that out
#
# 1679
# 01:26:07,989 --> 01:26:11,250
# too if
#
# 1680
# 01:26:19,949 --> 01:26:25,230
# this and this
#
# 1681
# 01:26:28,929 --> 01:26:34,120
# do you see that this is a finger if we
#
# 1682
# 01:26:32,170 --> 01:26:38,190
# go from the right and from the left and
#
# 1683
# 01:26:34,120 --> 01:26:38,190
# they both go to positive infinity and
#
# 1684
# 01:26:40,890 --> 01:26:51,720
# this was your question yes
#
# 1685
# 01:26:48,780 --> 01:26:53,400
# sure if the two if this works all time
#
# 1686
# 01:26:51,720 --> 01:26:55,410
# if the left-sided limit and the right
#
# 1687
# 01:26:53,400 --> 01:26:57,990
# sideline go to the same thing the limit
#
# 1688
# 01:26:55,410 --> 01:26:59,580
# exists you could substitute in if this
#
# 1689
# 01:26:57,990 --> 01:27:01,080
# is going to negative fifty at negative
#
# 1690
# 01:26:59,580 --> 01:27:03,380
# three that would be negative finish so
#
# 1691
# 01:27:01,080 --> 01:27:05,880
# you can draw that that corollary as well
#
# 1692
# 01:27:03,380 --> 01:27:09,240
# good question any other good point any
#
# 1693
# 01:27:05,880 --> 01:27:12,710
# other questions before we continue all
#
# 1694
# 01:27:09,240 --> 01:27:12,710
# right let's compute some limits
#
# 1695
# 01:27:19,150 --> 01:27:22,450
# you get that
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-4e0b68ea3d19> in <module>
# ----> 1 getTranscript(playlist)
#
# <ipython-input-18-cfe4620c047c> in getTranscript(p)
#      10         source = YouTube(link)
#      11
# ---> 12         en_caption = source.captions['a.en']
#      13
#      14         en_caption_convert_to_srt = (en_caption.generate_srt_captions())
#
# /opt/anaconda3/lib/python3.8/site-packages/pytube/query.py in __getitem__(self, i)
#     416
#     417     def __getitem__(self, i: str):
# --> 418         return self.lang_code_index[i]
#     419
#     420     def __len__(self) -> int:
#
# KeyError: 'a.en'

# %%
#video = playlist.videos[0]
#video.captions_tracks
#for video in playlist.videos
link = playlist.video_urls[0]
print (link)
source = YouTube(link)
source.captions
# Out:
# https://www.youtube.com/watch?v=fYyARMqiaag
# {'a.en': <Caption lang="English (auto-generated)" code="a.en">}
